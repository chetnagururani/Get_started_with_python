# %% [markdown]
# # Dictonaries
# - Dictionaries are ordered collections of unique items stored in(key-value) pairs. key    and value pair are treated as single items.
# - Changeable and do not allow duplicates.
# 1. Unordered: Dictionaries have defined orders and will not be changed.
# 2. Unique: The keys in dictionaries should be unique. If we store any value with a key that already exists, then the most recent value will replace the old value
# 3. Changeable:
# Dictionaries are changeable, meaning that we can change, add or remove     items after the dictionary has been created.
# 4. keys must unique and of immutable data type(string, int, float,tuple)
# 5. Mutable

# %% [markdown]
# - Ordered or Unordered?
# - As of Python version 3.7, dictionaries are ordered. In Python 3.6 and earlier, dictionaries are unordered.

# %% [markdown]
# <b> Dictionary Length
# - To determine how many items a dictionary has, use the len() function:

# %%
fruit= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120}
len(fruit)
# Out:
# 5

# %%
fruit= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90} #
# if we repeate key then
len(fruit)
# Out:
# 5

# %% [markdown]
# <b> The dict() Constructor

# %%
t = dict(name = "sam", age = 36, country = "Norway")
print(t)
# Out:
# {'name': 'sam', 'age': 36, 'country': 'Norway'}

# %% [markdown]
# <b> Creating dictionary

# %%
a= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120}
a
# Out:
# {'apple': 100, 'banana': 40, 'mango': 150, 'orange': 80, 'grapes': 120}

# %%
fruit= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90}
# if key are similar it will take last key which is similar
print(fruit)
# Out:
# {'apple': 90, 'banana': 40, 'mango': 150, 'orange': 80, 'grapes': 120}

# %%
a={'name':'akansha', 'class':1 , 'roll no.': '08'} # recent value

# %%
a={(1,2, 3, 4):'akansha', (2, 3,4, 5): 1} # tuple in dictionaries

# %%
a={1:23, "hello":"hii", "name": [1, 23, 45, 56]} # value can mutable or immutable

# %% [markdown]
# <b> Accessing Elements of a Dictionary
# - For accessing element you need a key

# %%
fruit= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120}
fruit["apple"]
# Out:
# 100

# %%
fruit= {"apple": 100, "banana": 40, "mango": 150, "orange": 80, "grapes": 120, "apple": 90}
fruit["apple"]
print(fruit)
# Out:
# {'apple': 90, 'banana': 40, 'mango': 150, 'orange': 80, 'grapes': 120}

# %% [markdown]
# <b> Traversing a Dictionary

# %%
fruit= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90}
for i in fruit:
    print(i)
    print(fruit[i])
# Out:
# apple
# 90
# banana
# 40
# mango
# 150
# orange
# 80
# grapes
# 120

# %%
fruit= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90}
for i in fruit:
    print(i,":",fruit[i])
# Out:
# apple : 90
# banana : 40
# mango : 150
# orange : 80
# grapes : 120

# %%
fruit= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90}
for item, price in fruit.items():
    print(item)
    print(price)
# Out:
# apple
# 90
# banana
# 40
# mango
# 150
# orange
# 80
# grapes
# 120

# %% [markdown]
# <b>1- Get keys
# - key method take no argument and print all keys

# %%
a= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90}
c=a.keys()
print(c)
print(type(c))
# Out:
# dict_keys(['apple', 'banana', 'mango', 'orange', 'grapes'])
# <class 'dict_keys'>

# %%
c.append("cherry")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 c.append("cherry")
#
# AttributeError: 'dict_keys' object has no attribute 'append'

# %% [markdown]
# <b>2- get values
# - To see the values in one go

# %%
a= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90}
print(a.values())
b=a.values()
print(type(b))
# Out:
# dict_values([90, 40, 150, 80, 120])
# <class 'dict_values'>

# %%
sum(a.values())
# Out:
# 480

# %% [markdown]
# <b>3. Indexing by key, Not Number
# - String can be used as a key
# - You can use a tuple as a key only if it's elements are immutable

# %%
a= {"apple": 100,"banana": 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90}
a["apple"]
# Out:
# 140721665230040

# %%
a= {"apple": 100,("banana", "grape"): 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90}
print(a["banana", "grape"])
#or
print(a[("banana", "grape")])
# Out:
# 40
# 40

# %% [markdown]
# <b>4. Mutable
# - dictionary is also mutable . We can change the value of a certain key"in place" using the assignment statement as per syntax:

# %%
a= {"apple": 100,("banana", "grape"): 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90}
a["apple"]= 30
print(a)
# Out:
# {'apple': 30, ('banana', 'grape'): 40, 'mango': 150, 'orange': 80, 'grapes': 120}

# %%
a= {"apple": 100,("banana", "grape"): 40,"mango": 150,"orange": 80,"grapes": 120,"apple": 90}
a["cherry"]= 100 # for adding key must be unique neither it will change the existing key
print(a)
# Out:
# {'apple': 90, ('banana', 'grape'): 40, 'mango': 150, 'orange': 80, 'grapes': 120, 'cherry': 100}

# %% [markdown]
# <b> Hash-function is an internal algorithm to map and link a key with a stored value

# %%
# Specify keys separetely and corresponding values separately.
# In this methods the key and the values are closed inside a parentheses and are give as the argument
# to the zip() function , which is then given argument of dict().

# %%
fruits=dict(zip(('apple', 'grape', 'mango', 'orange',  'cherry'), (123, 100, 40, 50, 70)))
fruits
# Out:
# {'apple': 123, 'grape': 100, 'mango': 40, 'orange': 50, 'cherry': 70}

# %% [markdown]
# <b> 5. .update()

# %%
a={'india':'delhi', 'us':'washington'}
a.update({"england" : "London"})
hii hjdsklj are  i am fine

# %%
print(a)
# Out:
# {'india': 'delhi', 'us': 'washington', 'england': 'London'}

# %% [markdown]
# <b> 6. Deletion in dictionary

# %% [markdown]
# 1. .pop()
#  - It written the value of that key and remove the key and value from the list

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
a.pop("Italy")
# Out:
# 'Rome'

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
a.pop("japan")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[108], line 2
#       1 a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
# ----> 2 a.pop("japan")
#
# KeyError: 'japan'

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
a.pop("japan", "Not found")
# Out:
# 'Not found'

# %% [markdown]
# 2. .popitem()
# - return the item key and  value and remove it from dic

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
a.popitem()
# Out:
# ('Italy', 'Rome')

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
a.popitem("Ottawa")# take no argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 2
#       1 a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
# ----> 2 a.popitem("Ottawa"," not foun")
#
# TypeError: dict.popitem() takes no arguments (2 given)

# %% [markdown]
# 3. del statement
# - remove the item from dictionary or remove dictionary

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
del a ["Italy"]
print(a)
# Out:
# {'India': 'New Delhi', 'Canada': 'Ottawa', 'Australia': 'Canberra', 'Germany': 'Berlin', 'France': 'Paris'}

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
del a 
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 3
#       1 a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# <b>7. .formkeys()

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
a.fromkeys(["pakistan", "nepal", "bangladesh"], ["null", "none"])
# Out:
# {'pakistan': ['null', 'none'],
#  'nepal': ['null', 'none'],
#  'bangladesh': ['null', 'none']}

# %%
a.fromkeys("name", "bilong")
# Out:
# {'n': 'bilong', 'a': 'bilong', 'm': 'bilong', 'e': 'bilong'}

# %%
a.fromkeys([1, 2, 3, 4], "name")
# Out:
# {1: 'name', 2: 'name', 3: 'name', 4: 'name'}

# %%
a.fromkeys([1, 2, 3, 4, 5])
# Out:
# {1: None, 2: None, 3: None, 4: None, 5: None}

# %% [markdown]
# <b>8. .get()

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
print(a.get("India"))
#or
print(a["India"])
# Out:
# New Delhi
# New Delhi

# %% [markdown]
# <b>9. .items()

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
a.items()
# Out:
# dict_items([('India', 'New Delhi'), ('Canada', 'Ottawa'), ('Australia', 'Canberra'), ('Germany', 'Berlin'), ('France', 'Paris'), ('Italy', 'Rome')])

# %% [markdown]
# <b> 10. Checking for Existence a key

# %% [markdown]
# <b>1.

# %% [markdown]
# <b> - checking for existence of a key
# - [key] in [dictionary]

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
"Canada" in a
# Out:
# True

# %% [markdown]
# <b> Pretty printing a dictionary

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
print(a)
# Out:
# {'India': 'New Delhi', 'Canada': 'Ottawa', 'Australia': 'Canberra', 'Germany': 'Berlin', 'France': 'Paris', 'Italy': 'Rome'}

# %%
a= {"India": "New Delhi", "Canada": "Ottawa", "Australia": "Canberra", "Germany": "Berlin", "France": "Paris", "Italy": "Rome"}
print(json.dumps(a, indent=2))
# Out:
# {
#   "India": "New Delhi",
#   "Canada": "Ottawa",
#   "Australia": "Canberra",
#   "Germany": "Berlin",
#   "France": "Paris",
#   "Italy": "Rome"
# }

# %% [markdown]
# <b>. Counting Frequency of Elements in a list using Dictionary

# %%
text="The is sampling!"
words= text.split()

# %%
words
# Out:
# ['The', 'is', 'sampling!']

# %%
text="one, two, three"
words=text.split(",")
words
# Out:
# ['one', ' two', ' three']

# %%
# Program to count the frequency of a list- elements using a dictionary.

# %%
sentence ="This is a super idea This idea will change the idea of learning"
words = sentence.split()
d={}
for one in words:
    key=one
    if key not in d:
        count= words.count(key)
        d[key]=count
print("Counting frequencies in list \n", words)
print(d)
# Out:
# Counting frequencies in list
#  ['This', 'is', 'a', 'super', 'idea', 'This', 'idea', 'will', 'change', 'the', 'idea', 'of', 'learning']
# {'This': 2, 'is': 1, 'a': 1, 'super': 1, 'idea': 3, 'will': 1, 'change': 1, 'the': 1, 'of': 1, 'learning': 1}

# %% [markdown]
# <b> Dictionary Function

# %% [markdown]
# <b>1. len()

# %%
t = {"HR": 12, "Finance": 8, "Engineering": 25, "Marketing": 10, "Sales": 15, "IT": 7, "Operations": 20, "Legal": 5, "Customer Service": 18}
len(t)
# Out:
# 9

# %% [markdown]
# <b> 2. clear()

# %%
t = {"HR": 12, "Finance": 8, "Engineering": 25, "Marketing": 10, "Sales": 15, "IT": 7, "Operations": 20, "Legal": 5, "Customer Service": 18}
t.clear()
# clear the dictionary but dictionary is still present
